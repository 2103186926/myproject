# %%
import random

a = random.uniform(0.2,0.5)
print(a)

b =random.uniform(1,3)
print(b)
# Out:
# 0.38277561270762733
# 2.43774459402336

# %%
results = [{
                    'target_lat': 113,
                    'target_lon': 77,
                    'perturbed_lat': 113.052,
                    'perturbed_lon': 76.961,
                    'depth': 10,
                    'salinity': 3.133
            },
            {
                    'target_lat': 113,
                    'target_lon': 77,
                    'perturbed_lat': 113.051,
                    'perturbed_lon': 76.988,
                    'depth': 10,
                    'salinity': 3.188
            },
            {
                    'target_lat': 113,
                    'target_lon': 77,
                    'perturbed_lat': 113.048,
                    'perturbed_lon': 76.972,
                    'depth': 10,
                    'salinity': 3.145
            },
            {
                    'target_lat': 113,
                    'target_lon': 77,
                    'perturbed_lat': 113.046,
                    'perturbed_lon': 76.931,
                    'depth': 10,
                    'salinity': 3.115
            },
            {
                    'target_lat': 113,
                    'target_lon': 77,
                    'perturbed_lat': 113.046,
                    'perturbed_lon': 76.975,
                    'depth': 10,
                    'salinity': 3.135
            },
            {
                    'target_lat': 113,
                    'target_lon': 77,
                    'perturbed_lat': 113.046,
                    'perturbed_lon': 76.975,
                    'depth': 20,
                    'salinity': 3.235
            }
        ]

for result in results:
    d = result['depth']
    print(d)
# Out:
# 10
# 10
# 10
# 10
# 10
# 20

# %%
depth_salinity_map = {20:[38.4561,38.4612,38.4715],10:33.5501,30:33.5876,40:33.6214}

for depth,salinity in sorted(depth_salinity_map.items()):
    print(depth,salinity)
# Out:
# 10 33.5501
# 20 [38.4561, 38.4612, 38.4715]
# 30 33.5876
# 40 33.6214
